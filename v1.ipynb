# %%
import pandas as pd

# %%
raw = pd.read_csv("books_1.Best_Books_Ever.csv")

# %%
non_null_price = raw[raw['price'].notnull()]

# %%
selected_cols = ['bookId', 'title', 'author', 'rating', 'description', 'isbn', 'genres', 'coverImg', 'price']
selected = non_null_price[selected_cols]

# %%
non_null_description = selected[selected['description'].notnull()]

# %%
non_null_coverimg = non_null_description[non_null_description['coverImg'].notnull()]

# %%
cleaned = non_null_coverimg

# %%
cleaned.shape
# Out:
# (37323, 9)

# %%
cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37323 entries, 0 to 52477
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   bookId       37323 non-null  object
#  1   title        37323 non-null  object
#  2   author       37323 non-null  object
#  3   rating       37323 non-null  float64
#  4   description  37323 non-null  object
#  5   isbn         37323 non-null  object
#  6   genres       37323 non-null  object
#  7   coverImg     37323 non-null  object
#  8   price        37323 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 2.8+ MB

# %%
# number of duplicate values from each columns
duplicated_values = cleaned.apply(lambda x: x.duplicated().sum())

# %% [markdown]
# # Features that should be unique
# 1. bookID
# 2. isbn
# 3. title (doubt)
# 4. description (doubt)
# 5. coverImg

# %%
duplicated_values
# Out:
# bookId            32
# title           1445
# author         16591
# rating         37078
# description      103
# isbn              35
# genres          3296
# coverImg          32
# price          33622
# dtype: int64

# %%
cleaned.bookId.duplicated().sum()
# Out:
# 32

# %%
duplicated_bookIds = cleaned[cleaned.duplicated('bookId', keep=False)]

# %%
duplicated_bookIds
# Out:
#                                                 bookId  \
# 37377                         8794263-promises-to-keep
# 37378                                    1909590.Click
# 37380                               7544945-death-note
# 37381                                25886017-m-scaras
# 37382                    2669775-el-siglo-de-las-luces
# ...                                                ...
# 37480                              26845691-beatlebone
# 37481              22916606-gli-enigmi-dei-vedovi-neri
# 37482                                       13571757-1
# 37483  1481056.Gifts_and_Ministries_of_the_Holy_Spirit
# 37484                      27074409-deadly-class-vol-1
#
#                                          title  \
# 37377                         Promises to Keep
# 37378                                    Click
# 37380        Death Note: Black Edition, Vol. 2
# 37381                                 Máscaras
# 37382                    El siglo de las luces
# ...

# %%
desired_rows = cleaned[cleaned['bookId'] == '8794263-promises-to-keep']

# %%
unique_isbn_df = cleaned.drop_duplicates(subset=['isbn'])

# %%
unique_isbn_df.head()
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 4                               41865.Twilight
# 5                         19063.The_Book_Thief
# 6                           170448.Animal_Farm
#
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 4                                   Twilight
# 5                             The Book Thief
# 6                                Animal Farm
#
#                                               author  rating  \
# 0                                    Suzanne Collins    4.33
# 1          J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 4                                    Stephenie Meyer    3.60
# 5                    Markus Zusak (Goodreads Author)    4.37
# 6  George Orwell, Russell Baker (Preface), C.M. W...    3.95
#
# ...

# %%
duplicated_values = unique_isbn_df.apply(lambda x: x.duplicated().sum())

# %%
duplicated_values
# Out:
# bookId             0
# title           1410
# author         16556
# rating         37043
# description       71
# isbn               0
# genres          3261
# coverImg           0
# price          33587
# dtype: int64

# %%
unique_isbn_df
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 4                                   41865.Twilight
# 5                             19063.The_Book_Thief
# 6                               170448.Animal_Farm
# ...                                            ...
# 52470                   11115191-attracted-to-fire
# 52472                        12395883-unbelievable
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title  \
# 0                               The Hunger Games
# 1      Harry Potter and the Order of the Phoenix
# 4                                       Twilight
# 5                                 The Book Thief
# 6                                    Animal Farm
# ...

# %%
unique_description_df = unique_isbn_df.drop_duplicates(subset=['description'])

# %%
duplicated_values = unique_description_df.apply(lambda x: x.duplicated().sum())

# %%
duplicated_values
# Out:
# bookId             0
# title           1405
# author         16509
# rating         36972
# description        0
# isbn               0
# genres          3249
# coverImg           0
# price          33523
# dtype: int64

# %%
unique_description_df.shape
# Out:
# (37217, 9)

# %%
unique_description_df = unique_description_df.drop(columns=['bookId'])

# %%
unique_description_df.shape
# Out:
# (37217, 8)

# %%
unique_description_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37217 entries, 0 to 52477
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        37217 non-null  object
#  1   author       37217 non-null  object
#  2   rating       37217 non-null  float64
#  3   description  37217 non-null  object
#  4   isbn         37217 non-null  object
#  5   genres       37217 non-null  object
#  6   coverImg     37217 non-null  object
#  7   price        37217 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 2.6+ MB

# %%
unique_description_df.shape
# Out:
# (37217, 8)

# %%
unique_description_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37217 entries, 0 to 52477
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        37217 non-null  object
#  1   author       37217 non-null  object
#  2   rating       37217 non-null  float64
#  3   description  37217 non-null  object
#  4   isbn         37217 non-null  object
#  5   genres       37217 non-null  object
#  6   coverImg     37217 non-null  object
#  7   price        37217 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 2.6+ MB

# %%
rem_na = unique_description_df.dropna()

# %%
rem_na.shape
# Out:
# (37217, 8)

# %%
rem_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37217 entries, 0 to 52477
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        37217 non-null  object
#  1   author       37217 non-null  object
#  2   rating       37217 non-null  float64
#  3   description  37217 non-null  object
#  4   isbn         37217 non-null  object
#  5   genres       37217 non-null  object
#  6   coverImg     37217 non-null  object
#  7   price        37217 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 2.6+ MB

# %%
duplicated_values = rem_na.apply(lambda x: x.duplicated().sum())

# %%
df = rem_na

# %%
df.shape
# Out:
# (37217, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37217 entries, 0 to 52477
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        37217 non-null  object
#  1   author       37217 non-null  object
#  2   rating       37217 non-null  float64
#  3   description  37217 non-null  object
#  4   isbn         37217 non-null  object
#  5   genres       37217 non-null  object
#  6   coverImg     37217 non-null  object
#  7   price        37217 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 2.6+ MB

# %%
duplicated_values = df.apply(lambda x: x.duplicated().sum())

# %%
duplicated_values
# Out:
# title           1405
# author         16509
# rating         36972
# description        0
# isbn               0
# genres          3249
# coverImg           0
# price          33523
# dtype: int64

# %%
df.head()
# Out:
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 4                                   Twilight
# 5                             The Book Thief
# 6                                Animal Farm
#
#                                               author  rating  \
# 0                                    Suzanne Collins    4.33
# 1          J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 4                                    Stephenie Meyer    3.60
# 5                    Markus Zusak (Goodreads Author)    4.37
# 6  George Orwell, Russell Baker (Preface), C.M. W...    3.95
#
#                                          description           isbn  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  9780439023481
# 1  There is a door at the end of a silent corrido...  9780439358071
# 4  About three things I was absolutely positive.\...  9780316015844
# ...

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#    index                                      title  \
# 0      0                           The Hunger Games
# 1      1  Harry Potter and the Order of the Phoenix
# 2      4                                   Twilight
# 3      5                             The Book Thief
# 4      6                                Animal Farm
#
#                                               author  rating  \
# 0                                    Suzanne Collins    4.33
# 1          J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                    Stephenie Meyer    3.60
# 3                    Markus Zusak (Goodreads Author)    4.37
# 4  George Orwell, Russell Baker (Preface), C.M. W...    3.95
#
#                                          description           isbn  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  9780439023481
# 1  There is a door at the end of a silent corrido...  9780439358071
# 2  About three things I was absolutely positive.\...  9780316015844
# ...

# %%
df = df[:5500]

# %%
df_for_model = df[["title", "description"]]

# %%
df_for_model
# Out:
#                                           title  \
# 0                              The Hunger Games
# 1     Harry Potter and the Order of the Phoenix
# 2                                      Twilight
# 3                                The Book Thief
# 4                                   Animal Farm
# ...                                         ...
# 5495                        A Trip to the Stars
# 5496                                   Heavenly
# 5497        The Flight of the Feathered Serpent
# 5498                             If You Deceive
# 5499       Requiem for Humanity (Last Days, #1)
#
#                                             description
# 0     WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1     There is a door at the end of a silent corrido...
# 2     About three things I was absolutely positive.\...
# 3     Librarian's note: An alternate cover edition c...
# 4     Librarian's note: There is an Alternate Cover ...
# ...

# %%
# titles = list(df_for_model['description'])
titles = list(df['description'])

# %%
import tensorflow as tf
import tensorflow_hub as hub
# Out:
# WARNING:tensorflow:From c:\Users\ganes\anaconda3\envs\nlp-recommend\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
model = hub.load(model_url)
print('Model Loaded')
# Out:
# WARNING:tensorflow:From c:\Users\ganes\anaconda3\envs\nlp-recommend\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\ganes\anaconda3\envs\nlp-recommend\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\ganes\anaconda3\envs\nlp-recommend\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From c:\Users\ganes\anaconda3\envs\nlp-recommend\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# Model Loaded

# %%
def embed(texts):
    return model(texts)

# %%
embeddings = embed(titles)

# %%
from sklearn.neighbors import NearestNeighbors
nn = NearestNeighbors(n_neighbors=10)
nn.fit(embeddings)
# Out:
# NearestNeighbors(n_neighbors=10)

# %%
def recommend(text):
    emb = embed([text])
    neighbors = nn.kneighbors(emb, return_distance=False)[0]
    # return df_for_model['title'].iloc[neighbors].tolist()
    return df['title'].iloc[neighbors].tolist()

# %%
print('Recommended Books:')
recommend("harry potter")
# Out:
# Recommended Books:
# ['The Harry Potter Collection 1-4',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Harry Potter and the Chamber of Secrets',
#  'Harry Potter Collection',
#  'The Harry Potter trilogy',
#  'Fantastic Beasts and Where to Find Them',
#  'Harry Potter and the Cursed Child: Parts One and Two',
#  'Harry Potter and the Deathly Hallows',
#  'Quidditch Through the Ages',
#  'Fantastic Beasts and Where to Find Them: The Original Screenplay']

# %%
import pickle
pickle.dump(nn,open('pickle_files/nn.pkl','wb'))
pickle.dump(df,open('pickle_files/df.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pickle
# ----> 2 pickle.dump(nn,open('pickle_files/nn.pkl','wb'))
#       3 pickle.dump(df,open('pickle_files/df.pkl','wb'))
#
# NameError: name 'nn' is not defined
